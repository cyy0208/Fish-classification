# %% [markdown]
# ## 导入工具包

# %%
import os
from tqdm import tqdm

import numpy as np
import pandas as pd

from PIL import Image

import torch
import torch.nn.functional as F

# 有 GPU 就用 GPU，没有就用 CPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('device', device)
# Out:
# device cuda:0

# %% [markdown]
# ## 图像预处理

# %%
from torchvision import transforms

# # 训练集图像预处理：缩放裁剪、图像增强、转 Tensor、归一化
# train_transform = transforms.Compose([transforms.RandomResizedCrop(224),
#                                       transforms.RandomHorizontalFlip(),
#                                       transforms.ToTensor(),
#                                       transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
#                                      ])

# 测试集图像预处理-RCTN：缩放、裁剪、转 Tensor、归一化
test_transform = transforms.Compose([transforms.Resize(256),
                                     transforms.CenterCrop(224),
                                     transforms.ToTensor(),
                                     transforms.Normalize(
                                         mean=[0.485, 0.456, 0.406], 
                                         std=[0.229, 0.224, 0.225])
                                    ])

# %% [markdown]
# ## 载入测试集（和训练代码教程相同）

# %%
# 数据集文件夹路径
dataset_dir = '/media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb/cyy/work/图像分类/cutsave_split'
test_path = os.path.join(dataset_dir, 'val')
from torchvision import datasets
# 载入测试集
test_dataset = datasets.ImageFolder(test_path, test_transform)
print('测试集图像数量', len(test_dataset))
print('类别个数', len(test_dataset.classes))
print('各类别名称', test_dataset.classes)
# 载入类别名称 和 ID索引号 的映射字典
idx_to_labels =np.load('/media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb/cyy/work/图像分类/3-【Pytorch】迁移学习训练自己的图像分类模型/idx_to_labels.npy', allow_pickle=True).item()
# 获得类别名称
classes = list(idx_to_labels.values())
print(classes)
# Out:
# 测试集图像数量 3200
# 类别个数 4
# 各类别名称 ['medium', 'none', 'strong', 'weak']
# ['medium', 'none', 'strong', 'weak']

# %% [markdown]
# ## 导入训练好的模型

# %%
model = torch.load('/media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb/cyy/work/图像分类/3-【Pytorch】迁移学习训练自己的图像分类模型/checkpoints/best-0.926.pth')
model = model.eval().to(device)

# %% [markdown]
# ## 表格A-测试集图像路径及标注

# %%
test_dataset.imgs[:10]
# Out:
# [('/media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb/cyy/work/图像分类/cutsave_split/val/medium/medium00002.jpg',
#   0),
#  ('/media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb/cyy/work/图像分类/cutsave_split/val/medium/medium00003.jpg',
#   0),
#  ('/media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb/cyy/work/图像分类/cutsave_split/val/medium/medium00006.jpg',
#   0),
#  ('/media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb/cyy/work/图像分类/cutsave_split/val/medium/medium00009.jpg',
#   0),
#  ('/media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb/cyy/work/图像分类/cutsave_split/val/medium/medium00017.jpg',
#   0),
#  ('/media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb/cyy/work/图像分类/cutsave_split/val/medium/medium00022.jpg',
#   0),
#  ('/media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb/cyy/work/图像分类/cutsave_split/val/medium/medium00028.jpg',
#   0),
#  ('/media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb/cyy/work/图像分类/cutsave_split/val/medium/medium00044.jpg',
#   0),
#  ('/media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb/cyy/work/图像分类/cutsave_split/val/medium/medium00045.jpg',
#   0),
#  ('/media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb/cyy/work/图像分类/cutsave_split/val/medium/medium00047.jpg',
#   0)]

# %%
img_paths = [each[0] for each in test_dataset.imgs]

# %%
df = pd.DataFrame()
df['图像路径'] = img_paths
df['标注类别ID'] = test_dataset.targets
df['标注类别名称'] = [idx_to_labels[ID] for ID in test_dataset.targets]

# %%
df
# Out:
#                                                    图像路径  标注类别ID  标注类别名称
# 0     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 1     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 2     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 3     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 4     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 5     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 6     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 7     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 8     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 9     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 10    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 11    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 12    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 13    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 14    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 15    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 16    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 17    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 18    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 19    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 20    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 21    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 22    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 23    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 24    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 25    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 26    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 27    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 28    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 29    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# ...                                                 ...     ...     ...
# 3170  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3171  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3172  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3173  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3174  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3175  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3176  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3177  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3178  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3179  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3180  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3181  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3182  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3183  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3184  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3185  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3186  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3187  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3188  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3189  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3190  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3191  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3192  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3193  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3194  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3195  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3196  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3197  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3198  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3199  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
#
# [3200 rows x 3 columns]

# %% [markdown]
# ## 表格B-测试集每张图像的图像分类预测结果，以及各类别置信度

# %%
# 记录 top-n 预测结果
n = 3

# %%
df_pred = pd.DataFrame()
for idx, row in tqdm(df.iterrows()):
    img_path = row['图像路径']
    img_pil = Image.open(img_path).convert('RGB')
    input_img = test_transform(img_pil).unsqueeze(0).to(device) # 预处理
    pred_logits = model(input_img) # 执行前向预测，得到所有类别的 logit 预测分数
    pred_softmax = F.softmax(pred_logits, dim=1) # 对 logit 分数做 softmax 运算

    pred_dict = {}

    top_n = torch.topk(pred_softmax, n) # 取置信度最大的 n 个结果
    pred_ids = top_n[1].cpu().detach().numpy().squeeze() # 解析出类别
    
    # top-n 预测结果
    for i in range(1, n+1):
        pred_dict['top-{}-预测ID'.format(i)] = pred_ids[i-1]
        pred_dict['top-{}-预测名称'.format(i)] = idx_to_labels[pred_ids[i-1]]
    pred_dict['top-n预测正确'] = row['标注类别ID'] in pred_ids
    # 每个类别的预测置信度
    for idx, each in enumerate(classes):
        pred_dict['{}-预测置信度'.format(each)] = pred_softmax[0][idx].cpu().detach().numpy()
        
    df_pred = df_pred.append(pred_dict, ignore_index=True)
# Out:
# 3200it [02:41, 19.84it/s]

# %%
df_pred
# Out:
#       medium-预测置信度    none-预测置信度 strong-预测置信度  top-1-预测ID top-1-预测名称  \
# 0        0.7357371     0.0456867   0.08210941         0.0     medium
# 1       0.45540452    0.01306144   0.35999188         0.0     medium
# 2        0.7578047   0.009940599   0.17786004         0.0     medium
# 3       0.34346557   0.010454647    0.6322077         2.0     strong
# 4        0.4734628  0.0048073693    0.5154145         2.0     strong
# 5        0.7664874   0.012169804   0.20866151         0.0     medium
# 6       0.87741566  0.0052705775   0.10027949         0.0     medium
# 7        0.5865845   0.010732329   0.32103476         0.0     medium
# 8       0.80665386   0.014740202    0.1501817         0.0     medium
# 9       0.87622076  0.0043690037  0.112622544         0.0     medium
# 10      0.66075754  0.0074127275   0.29821947         0.0     medium
# 11      0.89296484    0.00537246   0.07060831         0.0     medium
# 12        0.939994  0.0023965456  0.028877245         0.0     medium
# 13       0.9001375  0.0011180212  0.089610666         0.0     medium
# 14      0.83570844   0.005946503   0.14727876         0.0     medium
# 15       0.7474247  0.0018810666   0.23894303         0.0     medium
# 16      0.91723377  0.0024077597   0.07307167         0.0     medium
# 17        0.950725  0.0019549392  0.039840292         0.0     medium
# 18      0.78575736  0.0028400875   0.17772484         0.0     medium
# 19       0.8840899  0.0017367072   0.09416862         0.0     medium
# 20       0.9222134  0.0014135157  0.065988466         0.0     medium
# 21        0.934549  0.0015225686   0.05532501         0.0     medium
# 22       0.9370572   0.005014677  0.048072882         0.0     medium
# 23      0.85716593  0.0054291254   0.11157803         0.0     medium
# 24       0.8283983   0.012987062   0.14095537         0.0     medium
# 25      0.94242483   0.003853433  0.030818986         0.0     medium
# 26       0.8883514   0.014373275   0.05894577         0.0     medium
# 27       0.8222023    0.00898327   0.05655646         0.0     medium
# 28       0.7943428   0.009781215    0.1711811         0.0     medium
# 29      0.82691795   0.042969912  0.093801655         0.0     medium
# ...            ...           ...          ...         ...        ...
# 3170    0.05029859    0.11819198  0.051378075         3.0       weak
# 3171   0.069822446    0.08856596   0.03061086         3.0       weak
# 3172    0.07855766    0.18178868   0.03890051         3.0       weak
# 3173    0.21023938    0.07044932  0.074635595         3.0       weak
# 3174    0.09139325    0.16345665   0.05695843         3.0       weak
# 3175    0.03930082   0.034180395   0.04089446         3.0       weak
# 3176   0.057147816    0.07017756  0.073751844         3.0       weak
# 3177   0.038966186   0.019451551  0.044137254         3.0       weak
# 3178   0.054708447   0.008820824   0.06383756         3.0       weak
# 3179   0.026622472   0.032319717  0.062013537         3.0       weak
# 3180   0.034496237    0.03039385   0.09468724         3.0       weak
# 3181   0.048512317   0.034255497    0.0854021         3.0       weak
# 3182   0.033566315   0.016821237  0.051130887         3.0       weak
# 3183   0.025494486    0.03259941   0.92470497         2.0     strong
# 3184    0.03400928    0.24853343    0.5597195         2.0     strong
# 3185   0.026756568    0.09193426   0.80425686         2.0     strong
# 3186   0.009468581    0.06391522    0.8080036         2.0     strong
# 3187   0.014164357    0.08378946    0.8589311         2.0     strong
# 3188  0.0072343955    0.06652793   0.88437897         2.0     strong
# 3189   0.009352562    0.20278297    0.7012425         2.0     strong
# 3190    0.23675549   0.007833935  0.025936207         3.0       weak
# 3191    0.13383287   0.019989703   0.01758384         3.0       weak
# 3192      0.089124   0.012480951  0.010216836         3.0       weak
# 3193    0.12718624    0.02788513  0.058985736         3.0       weak
# 3194    0.15285262   0.011990407    0.0330639         3.0       weak
# 3195   0.094638966   0.006004282  0.012468688         3.0       weak
# 3196    0.19326325   0.012250181  0.041629367         3.0       weak
# 3197    0.22316712   0.010996618   0.06193623         3.0       weak
# 3198     0.4529387   0.035008386  0.097803704         0.0     medium
# 3199      0.597244   0.017134245  0.061682653         0.0     medium
#
#       top-2-预测ID top-2-预测名称  top-3-预测ID top-3-预测名称  top-n预测正确    weak-预测置信度
# 0            3.0       weak         2.0     strong        1.0     0.1364668
# 1            2.0     strong         3.0       weak        1.0     0.1715422
# 2            2.0     strong         3.0       weak        1.0    0.05439465
# 3            0.0     medium         3.0       weak        1.0   0.013872127
# 4            0.0     medium         3.0       weak        1.0  0.0063154167
# 5            2.0     strong         3.0       weak        1.0   0.012681235
# 6            2.0     strong         3.0       weak        1.0   0.017034208
# 7            2.0     strong         3.0       weak        1.0   0.081648424
# 8            2.0     strong         3.0       weak        1.0   0.028424254
# 9            2.0     strong         3.0       weak        1.0  0.0067877215
# 10           2.0     strong         3.0       weak        1.0   0.033610236
# 11           2.0     strong         3.0       weak        1.0   0.031054402
# 12           2.0     strong         3.0       weak        1.0   0.028732141
# 13           2.0     strong         3.0       weak        1.0  0.0091338605
# 14           2.0     strong         3.0       weak        1.0   0.011066292
# 15           2.0     strong         3.0       weak        1.0   0.011751142
# 16           2.0     strong         3.0       weak        1.0   0.007286767
# 17           2.0     strong         3.0       weak        1.0   0.007479789
# 18           2.0     strong         3.0       weak        1.0    0.03367774
# 19           2.0     strong         3.0       weak        1.0    0.02000473
# 20           2.0     strong         3.0       weak        1.0   0.010384626
# 21           2.0     strong         3.0       weak        1.0   0.008603428
# 22           2.0     strong         3.0       weak        1.0    0.00985526
# 23           2.0     strong         3.0       weak        1.0   0.025826912
# 24           2.0     strong         3.0       weak        1.0    0.01765927
# 25           2.0     strong         3.0       weak        1.0   0.022902736
# 26           2.0     strong         3.0       weak        1.0    0.03832952
# 27           3.0       weak         2.0     strong        1.0   0.112257965
# 28           2.0     strong         3.0       weak        1.0   0.024694927
# 29           2.0     strong         1.0       none        1.0   0.036310505
# ...          ...        ...         ...        ...        ...           ...
# 3170         1.0       none         2.0     strong        1.0     0.7801313
# 3171         1.0       none         0.0     medium        1.0    0.81100076
# 3172         1.0       none         0.0     medium        1.0    0.70075315
# 3173         0.0     medium         2.0     strong        1.0    0.64467573
# 3174         1.0       none         0.0     medium        1.0     0.6881917
# 3175         2.0     strong         0.0     medium        1.0    0.88562435
# 3176         2.0     strong         1.0       none        1.0    0.79892284
# 3177         2.0     strong         0.0     medium        1.0     0.8974449
# 3178         2.0     strong         0.0     medium        1.0    0.87263316
# 3179         2.0     strong         1.0       none        1.0     0.8790443
# 3180         2.0     strong         0.0     medium        1.0    0.84042263
# 3181         2.0     strong         0.0     medium        1.0     0.8318301
# 3182         2.0     strong         0.0     medium        1.0     0.8984816
# 3183         1.0       none         0.0     medium        0.0   0.017201167
# 3184         1.0       none         3.0       weak        1.0    0.15773779
# 3185         1.0       none         3.0       weak        1.0    0.07705231
# 3186         3.0       weak         1.0       none        1.0    0.11861258
# 3187         1.0       none         3.0       weak        1.0    0.04311506
# 3188         1.0       none         3.0       weak        1.0   0.041858733
# 3189         1.0       none         3.0       weak        1.0   0.086621895
# 3190         0.0     medium         2.0     strong        1.0     0.7294743
# 3191         0.0     medium         1.0       none        1.0     0.8285936
# 3192         0.0     medium         1.0       none        1.0     0.8881782
# 3193         0.0     medium         2.0     strong        1.0     0.7859428
# 3194         0.0     medium         2.0     strong        1.0     0.8020931
# 3195         0.0     medium         2.0     strong        1.0     0.8868881
# 3196         0.0     medium         2.0     strong        1.0     0.7528572
# 3197         0.0     medium         2.0     strong        1.0    0.70390004
# 3198         3.0       weak         2.0     strong        1.0    0.41424918
# 3199         3.0       weak         2.0     strong        1.0    0.32393906
#
# [3200 rows x 11 columns]

# %% [markdown]
# ## 拼接AB两张表格

# %%
df = pd.concat([df, df_pred], axis=1)

# %%
df
# Out:
#                                                    图像路径  标注类别ID  标注类别名称  \
# 0     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 1     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 2     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 3     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 4     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 5     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 6     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 7     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 8     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 9     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 10    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 11    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 12    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 13    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 14    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 15    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 16    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 17    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 18    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 19    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 20    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 21    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 22    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 23    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 24    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 25    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 26    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 27    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 28    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 29    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# ...                                                 ...     ...     ...
# 3170  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3171  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3172  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3173  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3174  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3175  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3176  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3177  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3178  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3179  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3180  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3181  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3182  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3183  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3184  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3185  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3186  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3187  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3188  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3189  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3190  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3191  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3192  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3193  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3194  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3195  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3196  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3197  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3198  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3199  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
#
#       medium-预测置信度    none-预测置信度 strong-预测置信度  top-1-预测ID top-1-预测名称  \
# 0        0.7357371     0.0456867   0.08210941         0.0     medium
# 1       0.45540452    0.01306144   0.35999188         0.0     medium
# 2        0.7578047   0.009940599   0.17786004         0.0     medium
# 3       0.34346557   0.010454647    0.6322077         2.0     strong
# 4        0.4734628  0.0048073693    0.5154145         2.0     strong
# 5        0.7664874   0.012169804   0.20866151         0.0     medium
# 6       0.87741566  0.0052705775   0.10027949         0.0     medium
# 7        0.5865845   0.010732329   0.32103476         0.0     medium
# 8       0.80665386   0.014740202    0.1501817         0.0     medium
# 9       0.87622076  0.0043690037  0.112622544         0.0     medium
# 10      0.66075754  0.0074127275   0.29821947         0.0     medium
# 11      0.89296484    0.00537246   0.07060831         0.0     medium
# 12        0.939994  0.0023965456  0.028877245         0.0     medium
# 13       0.9001375  0.0011180212  0.089610666         0.0     medium
# 14      0.83570844   0.005946503   0.14727876         0.0     medium
# 15       0.7474247  0.0018810666   0.23894303         0.0     medium
# 16      0.91723377  0.0024077597   0.07307167         0.0     medium
# 17        0.950725  0.0019549392  0.039840292         0.0     medium
# 18      0.78575736  0.0028400875   0.17772484         0.0     medium
# 19       0.8840899  0.0017367072   0.09416862         0.0     medium
# 20       0.9222134  0.0014135157  0.065988466         0.0     medium
# 21        0.934549  0.0015225686   0.05532501         0.0     medium
# 22       0.9370572   0.005014677  0.048072882         0.0     medium
# 23      0.85716593  0.0054291254   0.11157803         0.0     medium
# 24       0.8283983   0.012987062   0.14095537         0.0     medium
# 25      0.94242483   0.003853433  0.030818986         0.0     medium
# 26       0.8883514   0.014373275   0.05894577         0.0     medium
# 27       0.8222023    0.00898327   0.05655646         0.0     medium
# 28       0.7943428   0.009781215    0.1711811         0.0     medium
# 29      0.82691795   0.042969912  0.093801655         0.0     medium
# ...            ...           ...          ...         ...        ...
# 3170    0.05029859    0.11819198  0.051378075         3.0       weak
# 3171   0.069822446    0.08856596   0.03061086         3.0       weak
# 3172    0.07855766    0.18178868   0.03890051         3.0       weak
# 3173    0.21023938    0.07044932  0.074635595         3.0       weak
# 3174    0.09139325    0.16345665   0.05695843         3.0       weak
# 3175    0.03930082   0.034180395   0.04089446         3.0       weak
# 3176   0.057147816    0.07017756  0.073751844         3.0       weak
# 3177   0.038966186   0.019451551  0.044137254         3.0       weak
# 3178   0.054708447   0.008820824   0.06383756         3.0       weak
# 3179   0.026622472   0.032319717  0.062013537         3.0       weak
# 3180   0.034496237    0.03039385   0.09468724         3.0       weak
# 3181   0.048512317   0.034255497    0.0854021         3.0       weak
# 3182   0.033566315   0.016821237  0.051130887         3.0       weak
# 3183   0.025494486    0.03259941   0.92470497         2.0     strong
# 3184    0.03400928    0.24853343    0.5597195         2.0     strong
# 3185   0.026756568    0.09193426   0.80425686         2.0     strong
# 3186   0.009468581    0.06391522    0.8080036         2.0     strong
# 3187   0.014164357    0.08378946    0.8589311         2.0     strong
# 3188  0.0072343955    0.06652793   0.88437897         2.0     strong
# 3189   0.009352562    0.20278297    0.7012425         2.0     strong
# 3190    0.23675549   0.007833935  0.025936207         3.0       weak
# 3191    0.13383287   0.019989703   0.01758384         3.0       weak
# 3192      0.089124   0.012480951  0.010216836         3.0       weak
# 3193    0.12718624    0.02788513  0.058985736         3.0       weak
# 3194    0.15285262   0.011990407    0.0330639         3.0       weak
# 3195   0.094638966   0.006004282  0.012468688         3.0       weak
# 3196    0.19326325   0.012250181  0.041629367         3.0       weak
# 3197    0.22316712   0.010996618   0.06193623         3.0       weak
# 3198     0.4529387   0.035008386  0.097803704         0.0     medium
# 3199      0.597244   0.017134245  0.061682653         0.0     medium
#
#       top-2-预测ID top-2-预测名称  top-3-预测ID top-3-预测名称  top-n预测正确    weak-预测置信度
# 0            3.0       weak         2.0     strong        1.0     0.1364668
# 1            2.0     strong         3.0       weak        1.0     0.1715422
# 2            2.0     strong         3.0       weak        1.0    0.05439465
# 3            0.0     medium         3.0       weak        1.0   0.013872127
# 4            0.0     medium         3.0       weak        1.0  0.0063154167
# 5            2.0     strong         3.0       weak        1.0   0.012681235
# 6            2.0     strong         3.0       weak        1.0   0.017034208
# 7            2.0     strong         3.0       weak        1.0   0.081648424
# 8            2.0     strong         3.0       weak        1.0   0.028424254
# 9            2.0     strong         3.0       weak        1.0  0.0067877215
# 10           2.0     strong         3.0       weak        1.0   0.033610236
# 11           2.0     strong         3.0       weak        1.0   0.031054402
# 12           2.0     strong         3.0       weak        1.0   0.028732141
# 13           2.0     strong         3.0       weak        1.0  0.0091338605
# 14           2.0     strong         3.0       weak        1.0   0.011066292
# 15           2.0     strong         3.0       weak        1.0   0.011751142
# 16           2.0     strong         3.0       weak        1.0   0.007286767
# 17           2.0     strong         3.0       weak        1.0   0.007479789
# 18           2.0     strong         3.0       weak        1.0    0.03367774
# 19           2.0     strong         3.0       weak        1.0    0.02000473
# 20           2.0     strong         3.0       weak        1.0   0.010384626
# 21           2.0     strong         3.0       weak        1.0   0.008603428
# 22           2.0     strong         3.0       weak        1.0    0.00985526
# 23           2.0     strong         3.0       weak        1.0   0.025826912
# 24           2.0     strong         3.0       weak        1.0    0.01765927
# 25           2.0     strong         3.0       weak        1.0   0.022902736
# 26           2.0     strong         3.0       weak        1.0    0.03832952
# 27           3.0       weak         2.0     strong        1.0   0.112257965
# 28           2.0     strong         3.0       weak        1.0   0.024694927
# 29           2.0     strong         1.0       none        1.0   0.036310505
# ...          ...        ...         ...        ...        ...           ...
# 3170         1.0       none         2.0     strong        1.0     0.7801313
# 3171         1.0       none         0.0     medium        1.0    0.81100076
# 3172         1.0       none         0.0     medium        1.0    0.70075315
# 3173         0.0     medium         2.0     strong        1.0    0.64467573
# 3174         1.0       none         0.0     medium        1.0     0.6881917
# 3175         2.0     strong         0.0     medium        1.0    0.88562435
# 3176         2.0     strong         1.0       none        1.0    0.79892284
# 3177         2.0     strong         0.0     medium        1.0     0.8974449
# 3178         2.0     strong         0.0     medium        1.0    0.87263316
# 3179         2.0     strong         1.0       none        1.0     0.8790443
# 3180         2.0     strong         0.0     medium        1.0    0.84042263
# 3181         2.0     strong         0.0     medium        1.0     0.8318301
# 3182         2.0     strong         0.0     medium        1.0     0.8984816
# 3183         1.0       none         0.0     medium        0.0   0.017201167
# 3184         1.0       none         3.0       weak        1.0    0.15773779
# 3185         1.0       none         3.0       weak        1.0    0.07705231
# 3186         3.0       weak         1.0       none        1.0    0.11861258
# 3187         1.0       none         3.0       weak        1.0    0.04311506
# 3188         1.0       none         3.0       weak        1.0   0.041858733
# 3189         1.0       none         3.0       weak        1.0   0.086621895
# 3190         0.0     medium         2.0     strong        1.0     0.7294743
# 3191         0.0     medium         1.0       none        1.0     0.8285936
# 3192         0.0     medium         1.0       none        1.0     0.8881782
# 3193         0.0     medium         2.0     strong        1.0     0.7859428
# 3194         0.0     medium         2.0     strong        1.0     0.8020931
# 3195         0.0     medium         2.0     strong        1.0     0.8868881
# 3196         0.0     medium         2.0     strong        1.0     0.7528572
# 3197         0.0     medium         2.0     strong        1.0    0.70390004
# 3198         3.0       weak         2.0     strong        1.0    0.41424918
# 3199         3.0       weak         2.0     strong        1.0    0.32393906
#
# [3200 rows x 14 columns]

# %% [markdown]
# ## 导出完整表格

# %%
df.to_csv('测试集预测结果new VGG16.csv', index=False)
