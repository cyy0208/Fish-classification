# %% [markdown]
# ## 导入工具包

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# ## 载入类别名称和ID

# %%
idx_to_labels = np.load('/media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb/cyy/work/图像分类/3-【Pytorch】迁移学习训练自己的图像分类模型/idx_to_labels.npy', allow_pickle=True).item()
# 获得类别名称
classes = list(idx_to_labels.values())
print(classes)
# Out:
# ['medium', 'none', 'strong', 'weak']

# %% [markdown]
# ## 载入测试集预测结果表格

# %%
df = pd.read_csv('/media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb/cyy/work/图像分类/5-【Pytorch】在测试集上评估图像分类算法精度/测试集预测结果SHC.csv')

# %%
df
# Out:
#                                                    图像路径  标注类别ID  标注类别名称  \
# 0     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 1     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 2     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 3     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 4     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 5     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 6     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 7     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 8     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 9     /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 10    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 11    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 12    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 13    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 14    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 15    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 16    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 17    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 18    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 19    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 20    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 21    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 22    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 23    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 24    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 25    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 26    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 27    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 28    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# 29    /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       0  medium
# ...                                                 ...     ...     ...
# 3170  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3171  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3172  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3173  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3174  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3175  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3176  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3177  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3178  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3179  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3180  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3181  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3182  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3183  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3184  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3185  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3186  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3187  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3188  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3189  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3190  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3191  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3192  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3193  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3194  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3195  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3196  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3197  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3198  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
# 3199  /media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb...       3    weak
#
#       medium-预测置信度  none-预测置信度  strong-预测置信度  top-1-预测ID top-1-预测名称  \
# 0         0.475276    0.174892      0.174906         0.0     medium
# 1         0.474603    0.174998      0.175049         0.0     medium
# 2         0.471545    0.175476      0.177464         0.0     medium
# 3         0.473417    0.175184      0.176214         0.0     medium
# 4         0.474309    0.175044      0.175602         0.0     medium
# 5         0.475176    0.174908      0.175008         0.0     medium
# 6         0.475194    0.174905      0.174996         0.0     medium
# 7         0.475276    0.174892      0.174940         0.0     medium
# 8         0.474971    0.174940      0.175148         0.0     medium
# 9         0.473323    0.175199      0.176279         0.0     medium
# 10        0.424677    0.181839      0.211645         0.0     medium
# 11        0.456778    0.177677      0.187868         0.0     medium
# 12        0.475121    0.174917      0.175046         0.0     medium
# 13        0.475093    0.174921      0.175065         0.0     medium
# 14        0.472606    0.175311      0.176772         0.0     medium
# 15        0.475337    0.174882      0.174898         0.0     medium
# 16        0.475335    0.174883      0.174899         0.0     medium
# 17        0.475314    0.174886      0.174914         0.0     medium
# 18        0.475019    0.174933      0.175111         0.0     medium
# 19        0.475171    0.174909      0.175011         0.0     medium
# 20        0.475359    0.174879      0.174883         0.0     medium
# 21        0.475276    0.174892      0.174939         0.0     medium
# 22        0.475259    0.174895      0.174952         0.0     medium
# 23        0.475337    0.174882      0.174898         0.0     medium
# 24        0.475359    0.174879      0.174883         0.0     medium
# 25        0.475335    0.174883      0.174894         0.0     medium
# 26        0.475294    0.174889      0.174923         0.0     medium
# 27        0.470551    0.175630      0.178190         0.0     medium
# 28        0.472198    0.175375      0.177053         0.0     medium
# 29        0.475300    0.174888      0.174923         0.0     medium
# ...            ...         ...           ...         ...        ...
# 3170      0.174879    0.174879      0.174878         3.0       weak
# 3171      0.174878    0.174878      0.174878         3.0       weak
# 3172      0.174879    0.174880      0.174878         3.0       weak
# 3173      0.174879    0.174881      0.174879         3.0       weak
# 3174      0.174879    0.174883      0.174879         3.0       weak
# 3175      0.174885    0.174895      0.174882         3.0       weak
# 3176      0.174883    0.174892      0.174881         3.0       weak
# 3177      0.174879    0.174879      0.174878         3.0       weak
# 3178      0.174930    0.174890      0.174890         3.0       weak
# 3179      0.174878    0.174878      0.174878         3.0       weak
# 3180      0.174884    0.174882      0.174880         3.0       weak
# 3181      0.174885    0.174881      0.174880         3.0       weak
# 3182      0.175003    0.174907      0.174907         3.0       weak
# 3183      0.174916    0.174897      0.174895         3.0       weak
# 3184      0.174883    0.174888      0.174886         3.0       weak
# 3185      0.174892    0.174886      0.174897         3.0       weak
# 3186      0.174893    0.174891      0.174899         3.0       weak
# 3187      0.174878    0.174878      0.174878         3.0       weak
# 3188      0.174883    0.174888      0.174887         3.0       weak
# 3189      0.177102    0.176986      0.175768         3.0       weak
# 3190      0.174896    0.174886      0.174883         3.0       weak
# 3191      0.174888    0.174882      0.174880         3.0       weak
# 3192      0.174967    0.174899      0.174898         3.0       weak
# 3193      0.174940    0.174991      0.174911         3.0       weak
# 3194      0.174891    0.174931      0.174890         3.0       weak
# 3195      0.174882    0.174888      0.174880         3.0       weak
# 3196      0.175015    0.174926      0.174912         3.0       weak
# 3197      0.175485    0.175036      0.175021         3.0       weak
# 3198      0.175388    0.174995      0.174995         3.0       weak
# 3199      0.175223    0.174958      0.174957         3.0       weak
#
#       top-2-预测ID top-2-预测名称  top-3-预测ID top-3-预测名称  top-n预测正确  weak-预测置信度
# 0            3.0       weak         2.0     strong        1.0    0.174925
# 1            3.0       weak         2.0     strong        1.0    0.175349
# 2            2.0     strong         3.0       weak        1.0    0.175516
# 3            2.0     strong         3.0       weak        1.0    0.175185
# 4            2.0     strong         1.0       none        1.0    0.175044
# 5            2.0     strong         3.0       weak        1.0    0.174908
# 6            2.0     strong         3.0       weak        1.0    0.174905
# 7            2.0     strong         3.0       weak        1.0    0.174892
# 8            2.0     strong         3.0       weak        1.0    0.174940
# 9            2.0     strong         3.0       weak        1.0    0.175199
# 10           2.0     strong         3.0       weak        1.0    0.181840
# 11           2.0     strong         3.0       weak        1.0    0.177677
# 12           2.0     strong         3.0       weak        1.0    0.174917
# 13           2.0     strong         3.0       weak        1.0    0.174921
# 14           2.0     strong         1.0       none        1.0    0.175311
# 15           2.0     strong         3.0       weak        1.0    0.174883
# 16           2.0     strong         3.0       weak        1.0    0.174883
# 17           2.0     strong         3.0       weak        1.0    0.174886
# 18           2.0     strong         3.0       weak        1.0    0.174937
# 19           2.0     strong         3.0       weak        1.0    0.174909
# 20           2.0     strong         3.0       weak        1.0    0.174879
# 21           2.0     strong         3.0       weak        1.0    0.174893
# 22           2.0     strong         3.0       weak        1.0    0.174895
# 23           2.0     strong         1.0       none        1.0    0.174882
# 24           2.0     strong         3.0       weak        1.0    0.174879
# 25           2.0     strong         3.0       weak        1.0    0.174888
# 26           2.0     strong         3.0       weak        1.0    0.174893
# 27           2.0     strong         3.0       weak        1.0    0.175630
# 28           2.0     strong         3.0       weak        1.0    0.175375
# 29           2.0     strong         3.0       weak        1.0    0.174889
# ...          ...        ...         ...        ...        ...         ...
# 3170         0.0     medium         1.0       none        1.0    0.475364
# 3171         1.0       none         0.0     medium        1.0    0.475366
# 3172         1.0       none         0.0     medium        1.0    0.475363
# 3173         1.0       none         0.0     medium        1.0    0.475361
# 3174         1.0       none         0.0     medium        1.0    0.475359
# 3175         1.0       none         0.0     medium        1.0    0.475338
# 3176         1.0       none         0.0     medium        1.0    0.475344
# 3177         1.0       none         0.0     medium        1.0    0.475364
# 3178         0.0     medium         1.0       none        1.0    0.475290
# 3179         1.0       none         0.0     medium        1.0    0.475366
# 3180         0.0     medium         1.0       none        1.0    0.475354
# 3181         0.0     medium         1.0       none        1.0    0.475354
# 3182         0.0     medium         1.0       none        1.0    0.475184
# 3183         0.0     medium         1.0       none        1.0    0.475292
# 3184         1.0       none         2.0     strong        1.0    0.475344
# 3185         2.0     strong         0.0     medium        1.0    0.475324
# 3186         2.0     strong         0.0     medium        1.0    0.475317
# 3187         1.0       none         2.0     strong        1.0    0.475365
# 3188         1.0       none         2.0     strong        1.0    0.475342
# 3189         0.0     medium         1.0       none        1.0    0.470144
# 3190         0.0     medium         1.0       none        1.0    0.475335
# 3191         0.0     medium         1.0       none        1.0    0.475349
# 3192         0.0     medium         1.0       none        1.0    0.475235
# 3193         1.0       none         0.0     medium        1.0    0.475158
# 3194         1.0       none         0.0     medium        1.0    0.475288
# 3195         1.0       none         0.0     medium        1.0    0.475350
# 3196         0.0     medium         1.0       none        1.0    0.475147
# 3197         0.0     medium         1.0       none        1.0    0.474457
# 3198         0.0     medium         1.0       none        1.0    0.474622
# 3199         0.0     medium         1.0       none        1.0    0.474862
#
# [3200 rows x 14 columns]

# %% [markdown]
# ## 准确率

# %%
sum(df['标注类别名称'] == df['top-1-预测名称']) / len(df)
# Out:
# 0.9978125

# %% [markdown]
# ## top-n准确率

# %%
sum(df['top-n预测正确']) / len(df)
# Out:
# 1.0

# %% [markdown]
# ## 各类别其它评估指标
#
# 公众号 人工智能小技巧 回复 混淆矩阵
#
# 看子豪兄视频和笔记讲解

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(df['标注类别名称'], df['top-1-预测名称'], target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#       medium       0.99      1.00      1.00       800
#         none       1.00      1.00      1.00       800
#       strong       1.00      0.99      1.00       800
#         weak       1.00      1.00      1.00       800
#
#     accuracy                           1.00      3200
#    macro avg       1.00      1.00      1.00      3200
# weighted avg       1.00      1.00      1.00      3200

# %% [markdown]
# macro avg 宏平均：直接将每一类的评估指标求和取平均（算数平均值）
#
# weighted avg 加权平均：按样本数量（support）加权计算评估指标的平均值

# %%
report = classification_report(df['标注类别名称'], df['top-1-预测名称'], target_names=classes, output_dict=True)
del report['accuracy']
df_report = pd.DataFrame(report).transpose()

# %%
df_report
# Out:
#               f1-score  precision    recall  support
# medium        0.995633   0.993773  0.997500    800.0
# none          1.000000   1.000000  1.000000    800.0
# strong        0.995617   0.997491  0.993750    800.0
# weak          1.000000   1.000000  1.000000    800.0
# macro avg     0.997812   0.997816  0.997812   3200.0
# weighted avg  0.997812   0.997816  0.997812   3200.0

# %% [markdown]
# ## 补充：各类别准确率（其实就是recall）

# %%
accuracy_list = []
for fruit in tqdm(classes):
    df_temp = df[df['标注类别名称']==fruit]
    accuracy = sum(df_temp['标注类别名称'] == df_temp['top-1-预测名称']) / len(df_temp)
    accuracy_list.append(accuracy)
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 785.71it/s]

# %%
# 计算 宏平均准确率 和 加权平均准确率
acc_macro = np.mean(accuracy_list)
acc_weighted = sum(accuracy_list * df_report.iloc[:-2]['support'] / len(df))

accuracy_list.append(acc_macro)
accuracy_list.append(acc_weighted)

df_report['accuracy'] = accuracy_list

# %%
df_report
# Out:
#               f1-score  precision    recall  support  accuracy
# medium        0.995633   0.993773  0.997500    800.0  0.997500
# none          1.000000   1.000000  1.000000    800.0  1.000000
# strong        0.995617   0.997491  0.993750    800.0  0.993750
# weak          1.000000   1.000000  1.000000    800.0  1.000000
# macro avg     0.997812   0.997816  0.997812   3200.0  0.997812
# weighted avg  0.997812   0.997816  0.997812   3200.0  0.997812

# %%
df_report.to_csv('各类别准确率评估指标SHC.csv', index_label='类别')
