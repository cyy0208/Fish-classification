# %% [markdown]
# ## 导入工具包

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from mpl_toolkits.axes_grid1 import ImageGrid
# %matplotlib inline

import numpy as np
import math
import os

import cv2

from tqdm import tqdm

# %% [markdown]
# ## 指定要可视化图像的文件夹

# %%
folder_path = '/media/zy/600b4f4d-dc6c-4b45-8c58-476ec9afb3fb/cyy/work/图像分类/1-构建自己的图像分类数据集/cutsave_split/train/medium'

# %%
# 可视化图像的个数
N = 36

# %%
# n 行 n 列
n = math.floor(np.sqrt(N))
n
# Out:
# 6

# %% [markdown]
# ## 读取文件夹中的所有图像

# %%
images = []
for each_img in os.listdir(folder_path)[:N]:
    img_path = os.path.join(folder_path, each_img)
    img_bgr = cv2.imread(img_path)
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    images.append(img_rgb)

# %%
len(images)
# Out:
# 36

# %% [markdown]
# ## 画图

# %%
fig = plt.figure(figsize=(10, 10))
grid = ImageGrid(fig, 111,  # 类似绘制子图 subplot(111)
                 nrows_ncols=(n, n),  # 创建 n 行 m 列的 axes 网格
                 axes_pad=0.02,  # 网格间距
                 share_all=True
                 )

# 遍历每张图像
for ax, im in zip(grid, images):
    ax.imshow(im)
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_12355/2833584570.py:13: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
